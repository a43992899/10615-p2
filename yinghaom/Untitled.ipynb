# %%
# !pip install nltk
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
 
example_sent = "This is a sample sentence, showing off the stop words filtration."
 
stop_words = set(stopwords.words('english'))
 
word_tokens = word_tokenize(example_sent)
 
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
 
filtered_sentence = []
 
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

print(word_tokens)
print(filtered_sentence)

# %%
# !pip install wordcloud
# from wordcloud import WordCloud
# import matplotlib.pyplot as plt

# f = open(u"/home/yrb/code/jupyter/10615-p2/data/eastern.txt", "r", encoding="utf-8").read()
# wc = WordCloud(background_color="black", width=1500, height=960, margin=10).generate(f)
plt.imshow(wc)

# %%
# f = open(u"/home/yrb/code/jupyter/10615-p2/ziyi/eastern_bigram.txt", "r", encoding="utf-8").read()
# f = f.split("\n")
# f = [data.split("\t\t") for data in f]
bigram = []
for tuple_ in f:
    try:
        tmp = tuple_[0].split("'")
        tmp = f"{tmp[1]}_{tmp[3]}"
        for i in range(int(tuple_[1])):
            bigram.append(tmp)
    except:
        # print(tuple_)
        continue
bigram = " ".join(bigram)
wc = WordCloud(background_color="black", width=2000, height=1280, margin=10).generate(bigram)
plt.imshow(wc)

# %%
f = open(u"/home/yrb/code/jupyter/10615-p2/data/depression.txt", "r", encoding="utf-8").read()
wc = WordCloud(background_color="black", width=1500, height=960, margin=10).generate(f)
plt.imshow(wc)

# %%
f = open(u"/home/yrb/code/jupyter/10615-p2/ziyi/depression_bigram.txt", "r", encoding="utf-8").read()
f = f.split("\n")
f = [data.split("\t\t") for data in f]
bigram = []
for tuple_ in f:
    try:
        tmp = tuple_[0].split("'")
        tmp = f"{tmp[1]}_{tmp[3]}" 
        for i in range(int(tuple_[1])):
            bigram.append(tmp)
    except:
        print(tuple_)
bigram = "\n".join(bigram)
wc = WordCloud(background_color="black", width=2000, height=1290, margin=10).generate(bigram)
plt.imshow(wc)
# Out:
# ['']

# %%
f = open(u"/home/yrb/code/jupyter/10615-p2/data/philosophy+religion.txt", "r", encoding="utf-8").read()
wc = WordCloud(background_color="black", width=1500, height=960, margin=10).generate(f)
plt.imshow(wc)

# %%
# !cd ../data
# !ls
import os
name = os.listdir("/home/yrb/code/jupyter/10615-p2/data/eastern.txt")
name
# /home/yrb/code/jupyter/10615-p2/data/eastern
# Out:
# ['Zhuang Zi.txt',
#  'The Teaching of Buddha.txt',
#  '.ipynb_checkpoints',
#  'The Tao-te Ching.txt']
